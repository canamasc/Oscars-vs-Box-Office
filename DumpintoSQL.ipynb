# %%
import pandas as pd
from sqlalchemy import create_engine
from config import pw
import psycopg2

# %%
filepath = "Resources/film_performance.csv"
df1 = pd.read_csv(filepath)

filepath = "Resources/movies.csv"
df2 = pd.read_csv(filepath)

# %%
engine = create_engine(f'postgresql://postgres:{pw}@localhost:5432/Movies')
connection = engine.raw_connection()

# %%
df1
# Out:
#      Year  WorldwideBox Office  DomesticBox Office  InternationalBox Office  \
# 0    2009         2.845900e+09         760507625.0             2.085392e+09
# 1    2009         2.845900e+09         760507625.0             2.085392e+09
# 2    2009         2.845900e+09         760507625.0             2.085392e+09
# 3    2009         2.845900e+09         760507625.0             2.085392e+09
# 4    2009         2.845900e+09         760507625.0             2.085392e+09
# ..    ...                  ...                 ...                      ...
# 919  2000         2.578052e+08         125548685.0             1.322566e+08
# 920  2000         2.578052e+08         125548685.0             1.322566e+08
# 921  2000         2.578052e+08         125548685.0             1.322566e+08
# 922  2000         2.578052e+08         125548685.0             1.322566e+08
# 923  2000         2.578052e+08         125548685.0             1.322566e+08
#
#                                               category  \
# 0                                        ART DIRECTION
# 1                                       CINEMATOGRAPHY
# 2                                            DIRECTING
# 3                                         FILM EDITING
# 4                               MUSIC (Original Score)
# ..                                                 ...
# 919                         ACTOR IN A SUPPORTING ROLE
# 920                          ACTRESS IN A LEADING ROLE
# 921                                          DIRECTING
# 922                                       BEST PICTURE
# 923  WRITING (Screenplay Written Directly for the S...
#
#                                                   name  winner  \
# 0    Production Design: Rick Carter and Robert Stro...    True
# 1                                          Mauro Fiore    True
# 2                                        James Cameron   False
# 3        Stephen Rivkin, John Refoua and James Cameron   False
# 4                                         James Horner   False
# ..                                                 ...     ...
# 919                                      Albert Finney   False
# 920                                      Julia Roberts    True
# 921                                  Steven Soderbergh   False
# 922  Danny DeVito, Michael Shamberg and Stacey Sher...   False
# 923                          Written by Susannah Grant   False
#
#      nomination count  Nomination ID  Movie ID
# 0                   9              0         0
# 1                   9              1         0
# 2                   9              2         0
# 3                   9              3         0
# 4                   9              4         0
# ..                ...            ...       ...
# 919                 5           1245       253
# 920                 5           1246       253
# 921                 5           1247       253
# 922                 5           1248       253
# 923                 5           1249       253
#
# [924 rows x 10 columns]
