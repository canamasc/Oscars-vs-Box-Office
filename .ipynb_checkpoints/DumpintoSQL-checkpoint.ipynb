# %%
import pandas as pd
from sqlalchemy import create_engine
from config import pw
import psycopg2

# %%
filepath = "Resources/film_performance.csv"
df1 = pd.read_csv(filepath)

filepath = "Resources/movies.csv"
df2 = pd.read_csv(filepath)

# %%
engine = create_engine(f'postgresql://postgres:{pw}@localhost:5432/Movies-Final')
connection = engine.raw_connection()

# %%
df1
# Out:
#      Year  WorldwideBoxOffice  DomesticBoxOffice  InternationalBoxOffice  \
# 0    2009        2.845900e+09        760507625.0            2.085392e+09
# 1    2009        2.845900e+09        760507625.0            2.085392e+09
# 2    2009        2.845900e+09        760507625.0            2.085392e+09
# 3    2009        2.845900e+09        760507625.0            2.085392e+09
# 4    2009        2.845900e+09        760507625.0            2.085392e+09
# ..    ...                 ...                ...                     ...
# 919  2000        2.578052e+08        125548685.0            1.322566e+08
# 920  2000        2.578052e+08        125548685.0            1.322566e+08
# 921  2000        2.578052e+08        125548685.0            1.322566e+08
# 922  2000        2.578052e+08        125548685.0            1.322566e+08
# 923  2000        2.578052e+08        125548685.0            1.322566e+08
#
#                                               category  winner  \
# ...

# %%
df1.to_sql('film_performance', con=engine, if_exists='replace')

# %%
df2.to_sql('movies', con=engine, if_exists = 'replace')

# %%
checkq = pd.read_sql_query('''SELECT * FROM film_performance''',
                          connection)
checkdf = pd.DataFrame(checkq, columns=checkq.columns)

# %%
checkdf
# Out:
#      index  Year  WorldwideBoxOffice  DomesticBoxOffice  \
# 0        0  2009        2.845900e+09        760507625.0
# 1        1  2009        2.845900e+09        760507625.0
# 2        2  2009        2.845900e+09        760507625.0
# 3        3  2009        2.845900e+09        760507625.0
# 4        4  2009        2.845900e+09        760507625.0
# ..     ...   ...                 ...                ...
# 919    919  2000        2.578052e+08        125548685.0
# 920    920  2000        2.578052e+08        125548685.0
# 921    921  2000        2.578052e+08        125548685.0
# 922    922  2000        2.578052e+08        125548685.0
# 923    923  2000        2.578052e+08        125548685.0
#
#      InternationalBoxOffice  \
# 0              2.085392e+09
# 1              2.085392e+09
# 2              2.085392e+09
# 3              2.085392e+09
# 4              2.085392e+09
# ..                      ...
# 919            1.322566e+08
# 920            1.322566e+08
# ...

# %%
checkq = pd.read_sql_query('''SELECT * FROM movies''',
                          connection)
checkdf = pd.DataFrame(checkq, columns=checkq.columns)
checkdf
# Out:
#      index                    film
# 0        0                  avatar
# 1        1       avengers: endgame
# 2        2                 titanic
# 3        3  avengers: infinity war
# 4        4           the lion king
# ..     ...                     ...
# 249    249         the lone ranger
# 250    250       blade runner 2049
# 251    251           out of africa
# 252    252         american hustle
# 253    253         erin brockovich
#
# [254 rows x 2 columns]
